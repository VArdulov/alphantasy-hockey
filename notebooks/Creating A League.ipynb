# %% [markdown]
# # Creating a League
#
# > In order to bake an apple pie, you must first invent the universe
#
# -Carl Sagan (I think...)
#
# To evaluate our modelling approaches and get a feel for what kind of data needs to be pulled from the real world let's begin by first.
#
# Let's begin by importing the libraries that will be necessary to

# %%
import sys
print(sys.version)

from faker import Faker
import numpy as np
import scipy as sp
import pandas as pd
import datetime
# Out:
# 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]

# %% [markdown]
# Outline the teams in the league and how many games each team will play in the season

# %%
team_names = [
    "Hat-Trick Heroes",
    "No Woman, No Krejci",
    "Flying Elbows",
    "Fresh Prince of Briere",
    "The Lucky Pucks",
    "PCUK",
    "Blades of Steel",
    "Benchwarmers"
]

games_in_a_season = 4 * (len(team_names) - 1)
print(f"Games played in a season by each team: {games_in_a_season}")
# Out:
# Games played in a season by each team: 28

# %% [markdown]
# Generate a season schedule

# %%
for season in range(5):
    y = 2015 + season
    start_date = datetime.date(y, 10, 1)
    end_date = datetime.date(y+1, 5, 31)
    season_dates = pd.date_range(start_date, end_date, freq="D")

    schedules = {team_name:{"dates":[], "opponent":[]}for team_name in team_names}
    final_schedule = {"date": [], "team_1": [], "team_2":[]}

    for i, team_name in enumerate(team_names[:-1]):
        remaining_to_schedule = team_names[i+1:] * 4
        np.random.shuffle(remaining_to_schedule)
        for opponent in remaining_to_schedule:
            date = np.random.choice(season_dates)
            while date in schedules[team_name]["dates"] or date in schedules[opponent]["dates"]:
                date = np.random.choice(season_dates)

            schedules[team_name]["dates"].append(date)
            schedules[team_name]["opponent"].append(opponent)

            schedules[opponent]["dates"].append(date)
            schedules[opponent]["opponent"].append(team_name)

            final_schedule["date"].append(date)
            final_schedule["team_1"].append(team_name)
            final_schedule["team_2"].append(opponent)
    final_schedule_df = pd.DataFrame(final_schedule)
    final_schedule_df.to_csv(f"../data/schedules/season_{season}_{y}-{y+1}.csv", index=False)

# %%
final_schedule_df.sort_values(by="date", inplace=True, ignore_index=True)
print(
    f"First game of the season on {final_schedule_df.loc[0]['date']} "
    f"between {final_schedule_df.loc[0]['team_1']} and "
    f"{final_schedule_df.loc[len(final_schedule_df)-1]['team_2']}"
)
# Out:
# First game of the season on 2019-10-02 00:00:00 between Fresh Prince of Briere and Benchwarmers

# %% [markdown]
# Generate the players. First outline the positions stats and number of players per team

# %%
player_positions = ["C", "RW", "LW", "D", "G"]
positions_per_team = ["C"] * 2 + ["RW"] * 2 + ["LW"] * 2 +  ["D"] * 4 + ["G"] * 2 + ["B"] * 3
skater_stats_tracked = ["Goals", "Assists", "Hits", "Blocks"]
goalie_stats_tracked = ["Game_Starts", "Wins", "Saves"]
stats_distribution_scaling = {
    "Goals": (4, 2),
    "Assists": (5, 2),
    "Hits": (10, 5),
    "Blocks": (10, 5),
    "Game_Starts": (1, 0.5),
    "Wins": (1, 0.5),
    "Saves": (70, 15)
}

# %% [markdown]
# Use this to compute the number of players in the entire league

# %%
number_of_positions_per_team = len(positions_per_team)
number_of_players_in_the_league = int(len(team_names) * 1.1 * number_of_positions_per_team) + 1

# %%
fake = Faker()

# %%
league_players = {"name": [], "position": []}
for stat in skater_stats_tracked + goalie_stats_tracked:
    league_players[f"{stat}_mean"] = []
    league_players[f"{stat}_std"] = []

# %% [markdown]
# Generate the players proportionally to the positions available if the player is a bench player then make sure their position is generated randomly this guarantees that the minimum number of players cover each available slot on a teams roster.
#
# Then once the player is produced, generate average stats on the player to expect from them on a nightly basis. This will be used to simulate individual games throughout the season.

# %%
for i in range(number_of_players_in_the_league):
    player_name = fake.name()
    league_players["name"].append(player_name)
    
    n = len(positions_per_team)
    pos_idx = i % n
    pos = positions_per_team[pos_idx]
    if pos == "B":
        pos = np.random.choice(player_positions)
    league_players["position"].append(pos)
    
    print(f"Generated player {player_name} - position {pos}")
    for stat in stats_distribution_scaling:
        stat_mean = 0
        stat_std = 0
        
        if (pos == "G") == (stat in goalie_stats_tracked):
            m, s = stats_distribution_scaling[stat]
            stat_mean = m * np.random.random()
            stat_std = s * np.random.random()
            print(f"\t{stat}: {stat_mean:0.4f} (+/- {stat_std:0.4f})")
            
            
        league_players[f"{stat}_mean"].append(stat_mean)
        league_players[f"{stat}_std"].append(stat_std)
# Out:
# Generated player Anthony Morton - position C
# 	Goals: 1.6969 (+/- 1.0020)
# 	Assists: 3.5378 (+/- 1.2995)
# 	Hits: 5.8572 (+/- 0.8116)
# 	Blocks: 0.5520 (+/- 2.0598)
# Generated player Dr. Jennifer Mcmahon MD - position C
# 	Goals: 2.9016 (+/- 1.3534)
# 	Assists: 2.6320 (+/- 0.0607)
# 	Hits: 8.5561 (+/- 1.0019)
# 	Blocks: 3.5166 (+/- 4.1980)
# Generated player Andrea Beasley - position RW
# 	Goals: 1.8686 (+/- 0.8041)
# 	Assists: 3.7896 (+/- 0.1066)
# 	Hits: 6.1711 (+/- 3.6718)
# 	Blocks: 8.0691 (+/- 0.0155)
# Generated player Danny Harris - position RW
# 	Goals: 0.4706 (+/- 1.5677)
# 	Assists: 4.8558 (+/- 1.1372)
# 	Hits: 9.2897 (+/- 2.9577)
# 	Blocks: 2.1388 (+/- 1.1495)
# Generated player Martha Peterson - position LW
# 	Goals: 0.5225 (+/- 1.1198)
# 	Assists: 0.5976 (+/- 1.0578)
# 	Hits: 3.6838 (+/- 2.5148)
# 	Blocks: 6.1228 (+/- 4.7656)
# Generated player Loretta Wolfe - position LW
# 	Goals: 3.6220 (+/- 1.1712)
# 	Assists: 2.5358 (+/- 0.7803)
# 	Hits: 9.3753 (+/- 0.0468)
# 	Blocks: 3.2984 (+/- 1.3764)
# Generated player Antonio Hardy - position D
# 	Goals: 1.2771 (+/- 1.2991)
# 	Assists: 2.3929 (+/- 1.7522)
# 	Hits: 0.4747 (+/- 1.4797)
# 	Blocks: 4.6557 (+/- 0.2581)
# Generated player Daniel Montoya - position D
# 	Goals: 0.8996 (+/- 1.0252)
# 	Assists: 2.2646 (+/- 1.2501)
# 	Hits: 4.8444 (+/- 1.6712)
# 	Blocks: 2.5443 (+/- 1.3121)
# Generated player Mrs. Brandi King - position D
# 	Goals: 3.5487 (+/- 1.1270)
# 	Assists: 3.8475 (+/- 1.4462)
# 130         Brandon Martinez        G    0.000000   0.000000      0.000000
# 131              Kyle Nguyen        G    0.000000   0.000000      0.000000
# 132           Eric Middleton       RW    1.187281   0.376380      4.572941
#
#      Assists_std  Hits_mean  Hits_std  Blocks_mean  Blocks_std  \
# 0       1.299483   5.857164  0.811611     0.552004    2.059795
# 1       0.060701   8.556089  1.001882     3.516572    4.197982
# 2       0.106639   6.171108  3.671790     8.069108    0.015540
# 3       1.137198   9.289750  2.957675     2.138841    1.149527
# 4       1.057772   3.683814  2.514836     6.122802    4.765589
# ..           ...        ...       ...          ...         ...
# 128     0.584071   2.537578  3.738607     8.653453    1.195755
# 129     0.685769   1.716087  0.177707     0.577812    4.153256
# 130     0.000000   0.000000  0.000000     0.000000    0.000000
# 131     0.000000   0.000000  0.000000     0.000000    0.000000
# 132     0.918900   9.846945  1.573243     0.001948    1.447361
#
#      Game_Starts_mean  Game_Starts_std  Wins_mean  Wins_std  Saves_mean  \
# 0            0.000000         0.000000   0.000000  0.000000    0.000000
# 1            0.000000         0.000000   0.000000  0.000000    0.000000
# 2            0.000000         0.000000   0.000000  0.000000    0.000000
# 3            0.000000         0.000000   0.000000  0.000000    0.000000
# 4            0.000000         0.000000   0.000000  0.000000    0.000000
# ..                ...              ...        ...       ...         ...
# 128          0.000000         0.000000   0.000000  0.000000    0.000000
# 129          0.000000         0.000000   0.000000  0.000000    0.000000
# 130          0.774188         0.248221   0.490285  0.292157    0.285805
# 131          0.988963         0.358524   0.654174  0.328952   51.481248
# 132          0.000000         0.000000   0.000000  0.000000    0.000000
#
#      Saves_std team
# 0     0.000000   FA
# 1     0.000000   FA
# 2     0.000000   FA
# 3     0.000000   FA
# 4     0.000000   FA
# ..         ...  ...
# 128   0.000000   FA
# 129   0.000000   FA
# 130   0.332366   FA
# 131   2.070831   FA
# 132   0.000000   FA
#
# [133 rows x 17 columns]

# %%
team_names_shuffled = team_names.copy()
positions_per_teamn_shuffled = positions_per_team.copy()
np.random.shuffle(positions_per_teamn_shuffled)
np.random.shuffle(team_names_shuffled)
pick_number = 1
for pos in positions_per_team:
    print(f"drafting {pos}")
    available_players = league_players_df.loc[league_players_df["team"] == "FA"]
    if pos != "B":
        available_players = available_players.loc[available_players["position"] == pos]
    
    drafted_players = np.random.choice(available_players.index, size=len(team_names), replace=False)
    np.random.shuffle(team_names_shuffled)
    for player, team in zip(drafted_players, team_names_shuffled):
        print(f"With pick number {pick_number} the {team} select {league_players_df.loc[player]['name']}")
        league_players_df.loc[player, "team"] = team        
        pick_number += 1
# Out:
# drafting C
# With pick number 1 the Benchwarmers select Kathy Allen
# With pick number 2 the Blades of Steel select Mary Gutierrez
# With pick number 3 the Flying Elbows select Dr. Jennifer Mcmahon MD
# With pick number 4 the The Lucky Pucks select Ethan Jones
# With pick number 5 the Fresh Prince of Briere select Robin Ford
# With pick number 6 the PCUK select Dr. Cheryl Burgess
# With pick number 7 the No Woman, No Krejci select Dean Bell
# With pick number 8 the Hat-Trick Heroes select Dustin Medina
# drafting C
# With pick number 9 the Hat-Trick Heroes select Lisa Long
# With pick number 10 the No Woman, No Krejci select David Montgomery
# With pick number 11 the Benchwarmers select Tara Robinson MD
# With pick number 12 the The Lucky Pucks select Christopher Young
# With pick number 13 the Blades of Steel select Pamela Stewart
# With pick number 14 the Fresh Prince of Briere select Timothy Brown
# With pick number 15 the Flying Elbows select Heidi Richardson
# With pick number 16 the PCUK select Lauren Gomez
# drafting RW
# With pick number 17 the No Woman, No Krejci select Erika Humphrey
# With pick number 18 the Benchwarmers select Michael Lawson
# With pick number 19 the PCUK select David Rose
# With pick number 20 the The Lucky Pucks select Timothy Oneill
# With pick number 21 the Hat-Trick Heroes select Antonio Tanner
# With pick number 22 the Fresh Prince of Briere select Yolanda Hill
# With pick number 23 the Flying Elbows select Sara White
# With pick number 24 the Blades of Steel select Tabitha Young
# drafting RW
# With pick number 25 the The Lucky Pucks select Eric Moreno
# With pick number 26 the Hat-Trick Heroes select Misty Richards
# With pick number 27 the Fresh Prince of Briere select David Franklin
# With pick number 28 the PCUK select Destiny Robertson
# With pick number 29 the Flying Elbows select Faith Robinson
# With pick number 30 the No Woman, No Krejci select Andrea Beasley
# With pick number 31 the Benchwarmers select Mark Brown
# With pick number 32 the Blades of Steel select Diana Walker
# drafting LW
# With pick number 33 the The Lucky Pucks select Russell Barrera
# With pick number 34 the Hat-Trick Heroes select Daniel Jackson
# With pick number 35 the PCUK select Martha Peterson
# With pick number 36 the No Woman, No Krejci select Michael Curtis
# With pick number 37 the Flying Elbows select Loretta Wolfe
# With pick number 38 the Benchwarmers select Thomas Harrison
# With pick number 39 the Blades of Steel select John Clark
# With pick number 40 the Fresh Prince of Briere select Leah Howell
# drafting LW
# With pick number 41 the No Woman, No Krejci select Katherine Perez
# With pick number 42 the Fresh Prince of Briere select Jacob Austin
# With pick number 43 the Benchwarmers select Haley Lane
# With pick number 44 the Flying Elbows select Abigail Wright
# With pick number 45 the Hat-Trick Heroes select David Lee
# With pick number 46 the PCUK select Samantha Gibbs
# With pick number 47 the Blades of Steel select Jennifer Lynch
# With pick number 48 the The Lucky Pucks select Paul Moore
# drafting D
# With pick number 49 the The Lucky Pucks select Scott Chambers
# With pick number 50 the Fresh Prince of Briere select Jasmin Mclaughlin
# With pick number 51 the No Woman, No Krejci select Rebecca Payne
# With pick number 52 the Hat-Trick Heroes select Nicole Rodriguez
# With pick number 53 the Blades of Steel select Sonya Townsend
# With pick number 54 the Benchwarmers select Nicholas Gibbs
# With pick number 55 the PCUK select Amanda Hughes
# With pick number 56 the Flying Elbows select Dwayne Anderson
# drafting D
# With pick number 57 the The Lucky Pucks select Jessica Scott MD
# With pick number 58 the PCUK select Steven Jones
# With pick number 59 the Blades of Steel select Shannon Mann
# With pick number 60 the Flying Elbows select Shane Hudson
# With pick number 61 the Fresh Prince of Briere select Barbara Lowe
# With pick number 62 the No Woman, No Krejci select Crystal Stewart
# With pick number 63 the Hat-Trick Heroes select Ronald Hill
# With pick number 64 the Benchwarmers select Stacy Malone
# drafting D
# With pick number 65 the PCUK select Emily Fleming
# With pick number 66 the Blades of Steel select Lynn Jones
# With pick number 67 the Hat-Trick Heroes select Kelly Edwards
# With pick number 68 the Flying Elbows select John Johnson
# With pick number 69 the Benchwarmers select Ryan Collins
# With pick number 70 the No Woman, No Krejci select Mrs. Brandi King
# With pick number 71 the The Lucky Pucks select Hannah Garrison
# With pick number 72 the Fresh Prince of Briere select Alan Wright
# drafting D
# With pick number 73 the PCUK select Keith Byrd
# With pick number 74 the Benchwarmers select Antonio Hardy
# With pick number 75 the Hat-Trick Heroes select Daniel Montoya
# With pick number 76 the No Woman, No Krejci select Timothy Chavez
# With pick number 77 the Fresh Prince of Briere select Eric Davis
# With pick number 78 the Flying Elbows select Amanda Bond
# With pick number 79 the The Lucky Pucks select Anna Ayala
# With pick number 80 the Blades of Steel select Debbie Burke
# drafting G
# With pick number 81 the Blades of Steel select Brandy Rodriguez
# With pick number 82 the Benchwarmers select Carmen Smith
# With pick number 83 the The Lucky Pucks select Sara Moore
# With pick number 84 the PCUK select Kenneth Schwartz
# With pick number 85 the Flying Elbows select Allen Garcia
# With pick number 86 the Fresh Prince of Briere select Jenny Baker
# With pick number 87 the Hat-Trick Heroes select Dana Mckinney
# With pick number 88 the No Woman, No Krejci select Patricia Johnson
# drafting G
# With pick number 89 the Benchwarmers select Adam Blanchard
# With pick number 90 the Flying Elbows select Max Dean
# With pick number 91 the Blades of Steel select Sharon Thomas
# With pick number 92 the No Woman, No Krejci select Kyle Nguyen
# With pick number 93 the PCUK select Emily Lindsey
# With pick number 94 the Hat-Trick Heroes select Diane Anderson
# With pick number 95 the Fresh Prince of Briere select Raymond Reese
# With pick number 96 the The Lucky Pucks select Destiny Garza
# drafting B
# With pick number 97 the Benchwarmers select Karen Sullivan
# With pick number 98 the Fresh Prince of Briere select Anthony Morton
# With pick number 99 the Blades of Steel select Patricia Hoffman
# With pick number 100 the The Lucky Pucks select Donna Hall
# With pick number 101 the Flying Elbows select Nathan Galvan
# With pick number 102 the No Woman, No Krejci select Anthony Salazar
# With pick number 103 the PCUK select Joshua Young
# With pick number 104 the Hat-Trick Heroes select Kathryn Moore
# drafting B
# With pick number 105 the Benchwarmers select Michele Bell
# With pick number 106 the Flying Elbows select Christine Sanchez
# With pick number 107 the Hat-Trick Heroes select Jose Smith
# With pick number 108 the No Woman, No Krejci select Stephanie Martinez
# With pick number 109 the Blades of Steel select Michelle Thompson
# With pick number 110 the PCUK select Danny Harris
# With pick number 111 the Fresh Prince of Briere select Jessica Henderson
# With pick number 112 the The Lucky Pucks select Benjamin Martinez
# drafting B
# With pick number 113 the Fresh Prince of Briere select Jordan Anderson
# With pick number 114 the Benchwarmers select Jay Moore
# With pick number 115 the PCUK select Elizabeth Hawkins
# With pick number 116 the No Woman, No Krejci select Kendra Clark
# With pick number 117 the The Lucky Pucks select Kenneth Wright
# With pick number 118 the Flying Elbows select Danielle Baker
# With pick number 119 the Blades of Steel select Ashley Arnold
# With pick number 120 the Hat-Trick Heroes select Ronald Galvan

# %%
league_players_df.to_csv("../data/league_players.csv", index=False)
